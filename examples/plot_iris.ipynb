# %%
from sklearn.datasets import load_iris
from nlp_utils.plot_utils import plot_col_group, plot_col_train_test
from nlp_utils.import_utils import pd, train_test_split

# %%
datasets = load_iris()
df_data = pd.DataFrame(datasets.data, columns=datasets.feature_names)
df_data['label'] = datasets.target
df_train, df_test = train_test_split(df_data, test_size=0.2, random_state=42)
print(df_train.shape, df_test.shape)
# Out:
# (120, 5) (30, 5)

# %%
df_train.head()
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 22                4.6               3.6                1.0               0.2
# 15                5.7               4.4                1.5               0.4
# 65                6.7               3.1                4.4               1.4
# 11                4.8               3.4                1.6               0.2
# 42                4.4               3.2                1.3               0.2
#
#     label
# 22      0
# 15      0
# 65      1
# 11      0
# 42      0

# %%
plot_col_group(df_data, 'sepal length (cm)')

# %%
plot_col_train_test(df_train, df_test, 'sepal length (cm)')
