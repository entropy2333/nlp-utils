# %%
# !pip install -q matplotlib_venn

# %%
from nlp_utils.plot_utils import plot_venn_2, plot_venn_3

# %%
plot_venn_2(
    {"apple", "banana", "orange", "pear"},
    {"banana", "orange", "pear", "kiwi"},
)
